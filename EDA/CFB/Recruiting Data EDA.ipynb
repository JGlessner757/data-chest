# %%
import numpy as np # linear algebra - is for nerds.
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from pandas import DataFrame, Series
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
# Command so that plots appear in the iPython Notebook
# %matplotlib inline

# %%
df = pd.read_csv('C:/Users/jgles/dawg/Analysis/Recruiting Data/HighSchool - 2000 Player Rankings.csv')
df
# Out:
#      ranking                   name                     School State  \
# 0          1          D.J. Williams                De La Salle    CA
# 1          2           Brock Berlin  Evangel Christian Academy    LA
# 2          3         Charles Rogers                    Saginaw    MI
# 3          4         Travis Johnson                 Notre Dame    CA
# 4          5         Marcus Houston           Thomas Jefferson    CO
# ..       ...                    ...                        ...   ...
# 115      116           Jason Witten               Elizabethton    TN
# 116      117          Lynn McGruder                   Cheyenne    NV
# 117      118       Dustin Picciotti         Central Bucks West    PA
# 118      119           Marcus White                   Theodore    AL
# 119      120  Nautyn McKay-Loescher                    Toronto    OH
#
#                 City position  height  weight  stars  rating         college
# 0            Concord      ILB   44349     235      5  0.9998           Miami
# 1         Shreveport      PRO   44349     190      5  0.9998         Florida
# 2            Saginaw       WR   44351     195      5  0.9988  Michigan State
# 3       Sherman Oaks      SDE   44351     265      5  0.9982   Florida State
# 4             Denver       RB   36678     208      5  0.9980        Colorado
# ..               ...      ...     ...     ...    ...     ...             ...
# 115     Elizabethton      WDE   44354     265      4  0.9606       Tennessee
# 116  North Las Vegas       DT   44350     285      4  0.9606       Tennessee
# 117       Doylestown       FB   44350     235      4  0.9602      Pittsburgh
# 118         Theodore      SDE   44352     270      4  0.9602          Auburn
# 119          Toronto      WDE   44351     240      4  0.9347         Alabama
#
# [120 rows x 11 columns]

# %%
df = df.drop(["height"], axis = 1)
df.head()
# Out:
#    ranking            name                     School State          City  \
# 0        1   D.J. Williams                De La Salle    CA       Concord
# 1        2    Brock Berlin  Evangel Christian Academy    LA    Shreveport
# 2        3  Charles Rogers                    Saginaw    MI       Saginaw
# 3        4  Travis Johnson                 Notre Dame    CA  Sherman Oaks
# 4        5  Marcus Houston           Thomas Jefferson    CO        Denver
#
#   position  weight  stars  rating         college
# 0      ILB     235      5  0.9998           Miami
# 1      PRO     190      5  0.9998         Florida
# 2       WR     195      5  0.9988  Michigan State
# 3      SDE     265      5  0.9982   Florida State
# 4       RB     208      5  0.9980        Colorado
